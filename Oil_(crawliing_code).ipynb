# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **Oil/USD**

# %%
url = "https://www.exchangerates.org.uk/commodities/OIL-USD-history.html"
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

prices = []
dates = []
rows = soup.find_all("tr")[2:]

for row in rows:
  price = row.find_all("td")[2].text.strip()
  prices.append(price)

for row in rows:
  date = row.find_all("td")[0].text.strip()
  dates.append(date)

df = pd.DataFrame({'Date': dates, 'oil': prices})
df

# %%
from datetime import datetime

def format_date(date_str):
    date_b = datetime.strptime(date_str, '%A %d %B %Y')

    date_n = date_b.strftime('%Y-%m-%d')
    return date_n

df["Date"] = df["Date"].apply(format_date)
df.sort_values(by='Date', ascending=True, inplace=True)
df["gold"] = pd.to_numeric(df["gold"])

df = df[ (df['Date'] >= '2014-01-01') & (df['Date'] <= '2022-12-31') ].reset_index(drop=True)

# %%
df.to_csv("US_oil.csv")

# %% [markdown]
# **Oil/GBP**

# %%
url = "https://www.exchangerates.org.uk/commodities/OIL-GBP-history.html"
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

prices = []
dates = []
rows = soup.find_all("tr")[2:]

for row in rows:
  price = row.find_all("td")[2].text.strip()
  prices.append(price)

for row in rows:
  date = row.find_all("td")[0].text.strip()
  dates.append(date)

df = pd.DataFrame({'Date': dates, 'oil': prices})
df
# Out:
#                             Date       oil
# 0           Tuesday 2 April 2024  68.03741
# 1            Monday 1 April 2024  66.85260
# 2           Sunday 31 March 2024  65.83611
# 3         Saturday 30 March 2024  65.84029
# 4           Friday 29 March 2024  65.84312
# ...                          ...       ...
# 4876  Wednesday 17 November 2010  50.78932
# 4877    Tuesday 16 November 2010  51.95001
# 4878     Monday 15 November 2010  52.64437
# 4879     Sunday 14 November 2010  52.53652
# 4880     Thursday 1 January 1970  65.85546
#
# [4881 rows x 2 columns]

# %%
from datetime import datetime

def format_date(date_str):
    date_b = datetime.strptime(date_str, '%A %d %B %Y')

    date_n = date_b.strftime('%Y-%m-%d')
    return date_n

df["Date"] = df["Date"].apply(format_date)
df.sort_values(by='Date', ascending=True).reset_index(inplace=True)
df
# Out:
#       index        Date       oil
# 0      4880  1970-01-01  65.85546
# 1      4879  2010-11-14  52.53652
# 2      4878  2010-11-15  52.64437
# 3      4877  2010-11-16  51.95001
# 4      4876  2010-11-17  50.78932
# ...     ...         ...       ...
# 4876      4  2024-03-29  65.84312
# 4877      3  2024-03-30  65.84029
# 4878      2  2024-03-31  65.83611
# 4879      1  2024-04-01  66.85260
# 4880      0  2024-04-02  68.03741
#
# [4881 rows x 3 columns]

# %%
df = df[ (df['Date'] >= '2014-01-01') & (df['Date'] <= '2022-12-31') ].reset_index(drop=True)
df["Date"] = pd.to_datetime(df["Date"])
df["oil"] = pd.to_numeric(df["oil"])
# Out:
#            Date       oil
# 0    2014-01-01  59.53400
# 1    2014-01-02  58.01280
# 2    2014-01-03  57.39620
# 3    2014-01-04  57.39620
# 4    2014-01-05  57.39110
# ...         ...       ...
# 3281 2022-12-27  66.31107
# 3282 2022-12-28  65.33603
# 3283 2022-12-29  65.20937
# 3284 2022-12-30  66.51100
# 3285 2022-12-31  66.51100
#
# [3286 rows x 2 columns]

# %%
df.to_csv("UK_oil.csv")
