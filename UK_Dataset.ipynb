# %%
# !pip install finance-datareader
# !pip install pykrx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.8/247.8 kB 16.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

import FinanceDataReader as fdr
from pykrx import stock
import pandas_datareader.data as pdr
import yfinance as yf
from datetime import datetime

# %% [markdown]
# **CSV 파일**

# %%
# 금

gold = pd.read_csv("UK_gold.csv", encoding="utf-8")
gold = gold.drop(columns="Unnamed: 0")
gold['Date'] = pd.to_datetime(gold['Date'], format='%Y-%m-%d')
gold["gold"] = gold["gold"].round(2)
gold
# Out:
#            Date     gold
# 0    2014-01-01   727.66
# 1    2014-01-02   743.80
# 2    2014-01-03   753.42
# 3    2014-01-04   753.42
# 4    2014-01-05   752.17
# ...         ...      ...
# 3281 2022-12-27  1507.11
# 3282 2022-12-28  1501.22
# 3283 2022-12-29  1505.73
# 3284 2022-12-30  1508.17
# 3285 2022-12-31  1508.17
#
# [3286 rows x 2 columns]

# %%
gold[gold["Date"].duplicated()]
# Out:
#            Date     gold
# 1164 2017-03-09   987.03
# 1170 2017-03-14   987.41
# 1179 2017-03-22   999.16
# 1187 2017-03-29  1007.30
# 1192 2017-04-02   995.64

# %%
gold = gold.drop_duplicates("Date", keep="last").reset_index(drop=True)
gold
# Out:
#            Date     gold
# 0    2014-01-01   727.66
# 1    2014-01-02   743.80
# 2    2014-01-03   753.42
# 3    2014-01-04   753.42
# 4    2014-01-05   752.17
# ...         ...      ...
# 3276 2022-12-27  1507.11
# 3277 2022-12-28  1501.22
# 3278 2022-12-29  1505.73
# 3279 2022-12-30  1508.17
# 3280 2022-12-31  1508.17
#
# [3281 rows x 2 columns]

# %%
# 원유

oil = pd.read_csv("UK_oil.csv", encoding="utf-8")
oil = oil.drop(columns="Unnamed: 0")
oil['Date'] = pd.to_datetime(oil['Date'], format='%Y-%m-%d')
oil["oil"] = oil["oil"].round(2)
oil
# Out:
#            Date    oil
# 0    2014-01-01  59.53
# 1    2014-01-02  58.01
# 2    2014-01-03  57.40
# 3    2014-01-04  57.40
# 4    2014-01-05  57.39
# ...         ...    ...
# 3281 2022-12-27  66.31
# 3282 2022-12-28  65.34
# 3283 2022-12-29  65.21
# 3284 2022-12-30  66.51
# 3285 2022-12-31  66.51
#
# [3286 rows x 2 columns]

# %%
oil[oil["Date"].duplicated()]
# Out:
#            Date    oil
# 1164 2017-03-09  40.77
# 1170 2017-03-14  39.87
# 1179 2017-03-22  38.70
# 1187 2017-03-29  39.85
# 1192 2017-04-02  40.33

# %%
oil = oil.drop_duplicates("Date", keep="last").reset_index(drop=True)
oil
# Out:
#            Date    oil
# 0    2014-01-01  59.53
# 1    2014-01-02  58.01
# 2    2014-01-03  57.40
# 3    2014-01-04  57.40
# 4    2014-01-05  57.39
# ...         ...    ...
# 3276 2022-12-27  66.31
# 3277 2022-12-28  65.34
# 3278 2022-12-29  65.21
# 3279 2022-12-30  66.51
# 3280 2022-12-31  66.51
#
# [3281 rows x 2 columns]

# %%
headlines = pd.read_csv("UK_news.csv", encoding="utf-8")
headlines = headlines.drop("Unnamed: 0", axis=1)
headlines
# Out:
#             Date                                           Headline
# 0     2014-01-01  North Korea: Kim Jong-un hails powerful uncle'...
# 1     2014-01-02  China-Japan tensions: Chef crashes balloon nea...
# 2     2014-01-03  'What's normal at your work that would blow an...
# 3     2014-01-04  'What's normal at your work that would blow an...
# 4     2014-01-05  Outrage over commercialisation plans for BBC W...
# ...          ...                                                ...
# 3282  2022-12-27  When should I take down my Christmas tree and ...
# 3283  2022-12-28  The One With.... Every Friends episode ranked ...
# 3284  2022-12-29  Boxing Day sales 2022 – live: The best deals t...
# 3285  2022-12-30  9 sex scenes the actors are mortified about Co...
# 3286  2022-12-31  New Year’s Eve 2022: Six of the best natural h...
#
# [3287 rows x 2 columns]

# %%
headlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      3287 non-null   object
#  1   Headline  3287 non-null   object
# dtypes: object(2)
# memory usage: 51.5+ KB

# %%
headlines['Date'] = pd.to_datetime(headlines['Date'])
headlines
# Out:
#            Date                                           Headline
# 0    2014-01-01  North Korea: Kim Jong-un hails powerful uncle'...
# 1    2014-01-02  China-Japan tensions: Chef crashes balloon nea...
# 2    2014-01-03  'What's normal at your work that would blow an...
# 3    2014-01-04  'What's normal at your work that would blow an...
# 4    2014-01-05  Outrage over commercialisation plans for BBC W...
# ...         ...                                                ...
# 3282 2022-12-27  When should I take down my Christmas tree and ...
# 3283 2022-12-28  The One With.... Every Friends episode ranked ...
# 3284 2022-12-29  Boxing Day sales 2022 – live: The best deals t...
# 3285 2022-12-30  9 sex scenes the actors are mortified about Co...
# 3286 2022-12-31  New Year’s Eve 2022: Six of the best natural h...
#
# [3287 rows x 2 columns]

# %% [markdown]
# **API**

# %%
bond = fdr.DataReader('IGLT.L', start="20140101", end="20221231")
bond["bond"] = bond["Close"].round(2)
bond = bond.drop(columns=["Open", "High", "Low", "Close", "Adj Close", "Volume"])
bond.reset_index(inplace=True)
bond
# Out:
#            Date   bond
# 0    2014-01-02  11.13
# 1    2014-01-03  11.16
# 2    2014-01-06  11.19
# 3    2014-01-07  11.20
# 4    2014-01-08  11.18
# ...         ...    ...
# 2269 2022-12-22  10.52
# 2270 2022-12-23  10.51
# 2271 2022-12-28  10.48
# 2272 2022-12-29  10.48
# 2273 2022-12-30  10.49
#
# [2274 rows x 2 columns]

# %%
# 환율
cad = fdr.DataReader('GBPCAD=X', start="20140101", end="20221231").reset_index()
cad["cad"] = cad["Close"].round(2)
cad = cad.drop(columns=["Open", "High", "Low", "Close", "Adj Close", "Volume"])
cad.reset_index(inplace=True)

cny = fdr.DataReader('GBPCNY=X', start="20140101", end="20221231").reset_index()
cny["cny"] = cny["Close"].round(2)
cny = cny.drop(columns=["Open", "High", "Low", "Close", "Adj Close", "Volume"])
cny.reset_index(inplace=True)

eur = fdr.DataReader('GBPEUR=X', start="20140101", end="20221231").reset_index()
eur["eur"] = eur["Close"].round(2)
eur = eur.drop(columns=["Open", "High", "Low", "Close", "Adj Close", "Volume"])
eur.reset_index(inplace=True)

jpy = fdr.DataReader('GBPJPY=X', start="20140101", end="20221231").reset_index()
jpy["jpy"] = jpy["Close"].round(2)
jpy = jpy.drop(columns=["Open", "High", "Low", "Close", "Adj Close", "Volume"])
jpy.reset_index(inplace=True, drop=True)

usd = fdr.DataReader('GBPUSD=X', start="20140101", end="20221231").reset_index()
usd["usd"] = usd["Close"].round(2)
usd = usd.drop(columns=["Open", "High", "Low", "Close", "Adj Close", "Volume"])
usd.reset_index(inplace=True, drop=True)

# %%
# 산업 ETF

ETF = fdr.DataReader('^BUKIND', start="20140101", end="20221231")
ETF["ETF"] = ETF["Close"].round(2)
ETF = ETF.drop(columns=["Open", "High", "Low", "Close", "Adj Close", "Volume"])
ETF.reset_index(inplace=True)
ETF
# Out:
#            Date       ETF
# 0    2014-01-02  15372.90
# 1    2014-01-03  15428.82
# 2    2014-01-06  15503.45
# 3    2014-01-07  15530.75
# 4    2014-01-08  15452.77
# ...         ...       ...
# 2281 2022-12-23  18359.19
# 2282 2022-12-27  18359.19
# 2283 2022-12-28  18472.29
# 2284 2022-12-29  18491.61
# 2285 2022-12-30  18314.14
#
# [2286 rows x 2 columns]

# %%
date_range = pd.date_range(start='2014-01-01', end='2022-12-31')
df_dates = pd.DataFrame(date_range, columns=['Date'])

# %%
df_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3287 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 25.8 KB

# %%
df = pd.merge(df_dates, headlines, on="Date", how="left")
df = pd.merge(df,gold, on="Date", how="left")
df = pd.merge(df,oil, on="Date", how="left")
df = pd.merge(df,bond, on="Date", how="left")

df = pd.merge(df,cad, on="Date", how="left")
df = pd.merge(df,cny, on="Date", how="left")
df = pd.merge(df,eur, on="Date", how="left")
df = pd.merge(df,jpy, on="Date", how="left")
df = pd.merge(df,usd, on="Date", how="left")
df = pd.merge(df,ETF, on="Date", how="left")

df = df[["Date", "Headline", "gold", "oil", "bond", "cad", "cny", "eur", "jpy", "usd", "ETF"]]
df
# Out:
#            Date                                           Headline     gold  \
# 0    2014-01-01  North Korea: Kim Jong-un hails powerful uncle'...   727.66
# 1    2014-01-02  China-Japan tensions: Chef crashes balloon nea...   743.80
# 2    2014-01-03  'What's normal at your work that would blow an...   753.42
# 3    2014-01-04  'What's normal at your work that would blow an...   753.42
# 4    2014-01-05  Outrage over commercialisation plans for BBC W...   752.17
# ...         ...                                                ...      ...
# 3282 2022-12-27  When should I take down my Christmas tree and ...  1507.11
# 3283 2022-12-28  The One With.... Every Friends episode ranked ...  1501.22
# 3284 2022-12-29  Boxing Day sales 2022 – live: The best deals t...  1505.73
# 3285 2022-12-30  9 sex scenes the actors are mortified about Co...  1508.17
# 3286 2022-12-31  New Year’s Eve 2022: Six of the best natural h...  1508.17
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      3287 non-null   datetime64[ns]
#  1   Headline  3287 non-null   object
#  2   gold      3281 non-null   float64
#  3   oil       3281 non-null   float64
#  4   bond      2274 non-null   float64
#  5   cad       2346 non-null   float64
#  6   cny       2346 non-null   float64
#  7   eur       2346 non-null   float64
#  8   jpy       2346 non-null   float64
#  9   usd       2345 non-null   float64
#  10  ETF       2286 non-null   float64
# dtypes: datetime64[ns](1), float64(9), object(1)
# memory usage: 282.6+ KB

# %%
df.describe()
# Out:
#                       Date         gold          oil         bond  \
# count                 3287  3281.000000  3281.000000  2274.000000
# mean   2018-07-02 00:00:00  1068.895419    45.581186    13.077067
# min    2014-01-01 00:00:00   695.800000     0.000000     9.560000
# 25%    2016-04-01 12:00:00   863.550000    35.040000    12.420000
# 50%    2018-07-02 00:00:00   991.940000    43.330000    13.120000
# 75%    2020-09-30 12:00:00  1305.840000    53.190000    13.840000
# max    2022-12-31 00:00:00  1575.230000    99.540000    15.160000
# std                    NaN   251.420630    15.073196     1.044438
#
#                cad          cny          eur          jpy          usd  \
# count  2346.000000  2346.000000  2346.000000  2346.000000  2345.000000
# mean      1.746424     9.001897     1.190742   154.217072     1.370235
# min       1.470000     7.470000     1.060000   125.960000     1.070000
# 25%       1.680000     8.660000     1.130000   141.330000     1.280000
# ...

# %%
df.to_csv("UK_research.csv")

# %%
df2 = df.copy()
df2 = df2.fillna(method='ffill').dropna()
df2
# Out:
#            Date                                           Headline     gold  \
# 1    2014-01-02  China-Japan tensions: Chef crashes balloon nea...   743.80
# 2    2014-01-03  'What's normal at your work that would blow an...   753.42
# 3    2014-01-04  'What's normal at your work that would blow an...   753.42
# 4    2014-01-05  Outrage over commercialisation plans for BBC W...   752.17
# 5    2014-01-06  Shia LaBeouf copies rapper Gucci Mane and feud...   754.10
# ...         ...                                                ...      ...
# 3282 2022-12-27  When should I take down my Christmas tree and ...  1507.11
# 3283 2022-12-28  The One With.... Every Friends episode ranked ...  1501.22
# 3284 2022-12-29  Boxing Day sales 2022 – live: The best deals t...  1505.73
# 3285 2022-12-30  9 sex scenes the actors are mortified about Co...  1508.17
# 3286 2022-12-31  New Year’s Eve 2022: Six of the best natural h...  1508.17
#
# ...

# %%
df2.to_csv("UK_research2.csv")

# %%
df2
# Out:
#            Date                                           Headline     gold  \
# 1    2014-01-02  China-Japan tensions: Chef crashes balloon nea...   743.80
# 2    2014-01-03  'What's normal at your work that would blow an...   753.42
# 3    2014-01-04  'What's normal at your work that would blow an...   753.42
# 4    2014-01-05  Outrage over commercialisation plans for BBC W...   752.17
# 5    2014-01-06  Shia LaBeouf copies rapper Gucci Mane and feud...   754.10
# ...         ...                                                ...      ...
# 3282 2022-12-27  When should I take down my Christmas tree and ...  1507.11
# 3283 2022-12-28  The One With.... Every Friends episode ranked ...  1501.22
# 3284 2022-12-29  Boxing Day sales 2022 – live: The best deals t...  1505.73
# 3285 2022-12-30  9 sex scenes the actors are mortified about Co...  1508.17
# 3286 2022-12-31  New Year’s Eve 2022: Six of the best natural h...  1508.17
#
# ...
